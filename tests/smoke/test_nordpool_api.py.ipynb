-- %%
%python

# Manually fetch the elering prices and display them in a dataframe

from src.nordpool_api import fetch_elering_prices

records = fetch_elering_prices(
    days_back=2,
    days_forward=2,
)

df = spark.createDataFrame(records)
display(df)
